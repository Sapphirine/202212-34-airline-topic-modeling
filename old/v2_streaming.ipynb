# %%
import requests
import os
import json

# To set your enviornment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'
# bearer_token = os.environ.get("BEARER_TOKEN")
bearer_token = "AAAAAAAAAAAAAAAAAAAAAElqjwEAAAAA8PRQduIf5nDumMCOqlgqpkL9QHo%3D7d4vdi0UEJNMs9SmNH8nEQf9acD08THiUvzkJq3VfQzQJ4SSEf"


def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2FilteredStreamPython"
    return r


def get_rules():
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream/rules", auth=bearer_oauth
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot get rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    return response.json()


def delete_all_rules(rules):
    if rules is None or "data" not in rules:
        return None

    ids = list(map(lambda rule: rule["id"], rules["data"]))
    payload = {"delete": {"ids": ids}}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        auth=bearer_oauth,
        json=payload
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot delete rules (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    print(json.dumps(response.json()))


def set_rules(delete):
    # You can adjust the rules if needed
    sample_rules = [
        {"value": "dog has:images", "tag": "dog pictures"},
        {"value": "cat has:images -grumpy", "tag": "cat pictures"},
    ]
    payload = {"add": sample_rules}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        auth=bearer_oauth,
        json=payload,
    )
    if response.status_code != 201:
        raise Exception(
            "Cannot add rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))


def get_stream(set):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream", auth=bearer_oauth, stream=True,
    )
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Cannot get stream (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    for i, response_line in enumerate(response.iter_lines()):
        if response_line:
            json_response = json.loads(response_line)
            print(json.dumps(json_response, indent=4, sort_keys=True))
            with open(f'fetched_tweets_{i}.json', 'a') as outfile:
                json.dump(json_response, outfile)
                #tf.write(data)


# def main():
#     rules = get_rules()
#     delete = delete_all_rules(rules)
#     set = set_rules(delete)
#     get_stream(set)


# if __name__ == "__main__":
#     main()

# %%
rules = get_rules()
# Out:
# {"data": [{"id": "1598203047641026560", "value": "(@united has:geo lang:en -from:united)", "tag": "united"}, {"id": "1598203047641026561", "value": "(@SpiritAirlines has:geo lang:en -from:SpiritAirlines)", "tag": "SpiritAirlines"}], "meta": {"sent": "2022-12-01T06:31:46.968Z", "result_count": 2}}

# %%
delete = delete_all_rules(rules)
# Out:
# {"meta": {"sent": "2022-12-01T06:31:47.948Z", "summary": {"deleted": 2, "not_deleted": 0}}}

# %%
r_set = set_rules(delete)
# Out:
# {"data": [{"value": "cat has:images -grumpy", "tag": "cat pictures", "id": "1598203189068709893"}, {"value": "dog has:images", "tag": "dog pictures", "id": "1598203189068709894"}], "meta": {"sent": "2022-12-01T06:31:49.026Z", "summary": {"created": 2, "not_created": 0, "valid": 2, "invalid": 0}}}

# %%
json.loads(response_line)['matching_rules'][0]['tag']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 json.loads(response_line)['matching_rules'][0]['tag']
#
# NameError: name 'response_line' is not defined

# %%
response = requests.get(
    "https://api.twitter.com/2/tweets/search/stream", auth=bearer_oauth, stream=True,
)
print(response.status_code)
if response.status_code != 200:
    raise Exception(
        "Cannot get stream (HTTP {}): {}".format(
            response.status_code, response.text
        )
    )
for i, response_line in enumerate(response.iter_lines()):
    if response_line:
        json_response = json.loads(response_line)
        print(json.dumps(json_response, indent=4, sort_keys=True))
        with open(f'fetched_tweets_{i}.json', 'a') as outfile:
            json.dump(json_response, outfile)
            #tf.write(data)
# Out:
# 200
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203205929775104"
#         ],
#         "id": "1598203205929775104",
#         "text": "RT @cat_auras: https://t.co/lVn69HPLqC"
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709893",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203209415553025"
#         ],
#         "id": "1598203209415553025",
#         "text": "RT @cat_munzisang: \ud070\uc77c\ub0a8.\n\ud604\uad00 \uc13c\uc11c\ub4f1\uc774 \ub728\ub610\ub97c \uc778\uc2dd\ud574\uc11c \ucf1c\uc9d0....\n\uc5b4\uc774\uc5c6\uc74c.....\n#\uace0\uc591\uc774\uc785\uc591 #\uc544\uae7d\uc774\uc785\uc591 #\uc0ac\uc9c0\ub9d0\uace0\uc785\uc591\ud558\uc138\uc694 #\uc784\uc2dc\ubcf4\ud638 https://t.co/TksumfiQMU"
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709893",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203212775198722"
#         ],
#         "id": "1598203212775198722",
#         "text": "RT @AkemikunLewds: Cat girl Seraphine~ \ud83d\ude3d\ud83d\udc96\u2728\n\nFull photo set is on my Patreon!! https://t.co/l3r3yh2etq"
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709893",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203214847168512"
#         ],
#         "id": "1598203214847168512",
#         "text": "].p&lt;/B7 If I had my dog I'd love to,\" #\u5973S #ATM\u5974 #\u5bf8\u6b62 #\u6bcd\u72d7 #\u8fde\u9ea6 #\u7ea2\u7eff\u706f #\u5c04\u5c4f #\u89c6\u9891 #\u54c4\u7761 #\u610f\u6deb #\u78d5\u70ae #\u804a\u5929 #\u4e1d\u889c #\u53cd\u5dee #\u6587\u7231 #\u5973m #\u7eff\u5e3d #\u5a07\u5598 #\u966a\u73a9  https://t.co/2hCbrve1Fh"
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709894",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203217267261441"
#         ],
#         "id": "1598203217267261441",
#         "text": "RT @cat_auras: https://t.co/lVn69HPLqC"
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709893",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203216751382528"
#         ],
#         "id": "1598203216751382528",
#         "text": "RT @cat_auras: https://t.co/lVn69HPLqC"
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709893",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203218848145408"
#         ],
#         "id": "1598203218848145408",
#         "text": "#\u4eba\u59bb #\u88f8\u804a #\u53cd\u5dee\u5a4a #\u5973s #\u798f\u5229\u59ec  https://t.co/nVfknjs5c6\nTell dog wonder which on home agreement."
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709894",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203221742583808"
#         ],
#         "id": "1598203221742583808",
#         "text": "RT @Kyoko_555: \u3082\u3075\u3082\u3075 #\u30e2\u30d5\u66dc\u65e5 \u4eca\u65e5\u3082 #TL\u306b\u732b\u3092\u6d41\u3059 #\u732b #\u4fdd\u8b77\u732b #cat #\u99d2\u732b #\u91cc\u89aa\u52df\u96c6 \u30b7\u30fc\u30d0\u3061\u3083\u3093 https://t.co/MlPb3ramkr"
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709893",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203222040055808"
#         ],
#         "id": "1598203222040055808",
#         "text": "RT @cat_auras: sleeping time \ud83d\udca4 https://t.co/O8mP4xyTCR"
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709893",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203226096295941"
#         ],
#         "id": "1598203226096295941",
#         "text": "RT @big_ear_cat: 19\u5e74\u7684\uff0c\u73b0\u5728\u770b\u6709\u70b9\u7ec6\u601d\u6050\u6781\u4e86 https://t.co/6KRXMNWWz3"
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709893",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203227127746561"
#         ],
#         "id": "1598203227127746561",
#         "text": "RT @boople__snoot: went to the renaissance festival today and ordered a foot long corn dog \u0ca5\u203f\u0ca5 https://t.co/l7cKMZbcSv"
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709894",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203227321040896"
#         ],
#         "id": "1598203227321040896",
#         "text": "Turquoise Bracelet,Cat's Eye Bracelets Pink/blue stone Bracelet S925 Sterling Silver Round Turquoise Bracelets Jewelry for wo FNWGLL4\n\nhttps://t.co/qa5aQDJ7Ax https://t.co/xJxWygnCgN"
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709893",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203227140653056"
#         ],
#         "id": "1598203227140653056",
#         "text": "RT @c2owh: The florist's son and his stray cat. https://t.co/34lkUQKH1X"
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709893",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203230097637382"
#         ],
#         "id": "1598203230097637382",
#         "text": "This baby.\n\nShe will not share the bed. And she keeps slipping out of her collar. Oh, and really wants to be an outside cat. https://t.co/YlNzspOK6c"
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709893",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203233272725510"
#         ],
#         "id": "1598203233272725510",
#         "text": "RT @cat_auras: https://t.co/lVn69HPLqC"
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709893",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203230454190080"
#         ],
#         "id": "1598203230454190080",
#         "text": "RT @cat_auras: https://t.co/ICmtCSt6Er"
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709893",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598203235134832645"
#         ],
#         "id": "1598203235134832645",
#         "text": "@dog_twon \n\u3054\u53c2\u52a0\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\uff01\n\n\u62bd\u9078\u306e\u7d50\u679c\u3001\n\u6b8b\u5ff5\u306a\u304c\u3089\u4eca\u56de\u306f\u30cf\u30ba\u30ec\u3068\u306a\u308a\u307e\u3059\u2026\uff01\n\n12\u670825\u65e5\u307e\u3067\u6bce\u65e5\u53c2\u52a0\u53ef\u80fd\u3067\u3059\u3002\u307e\u305f\u53c2\u52a0\u3057\u3066\u304f\u3060\u3055\u3044\u306d\uff01\n\n#\u30ad\u30e9\u30d1\u30e9\u300012\u67088\u65e5\u30ea\u30ea\u30fc\u30b9\u4e88\u5b9a\uff01\u4e8b\u524d\u767b\u9332\u306f\u3053\u3061\u3089\uff01\nhttps://t.co/RX99phkGiK https://t.co/7VcisO1L2b"
#     },
#     "matching_rules": [
#         {
#             "id": "1598203189068709894",
#             "tag": "dog pictures"
#         }
#     ]
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [6], line 11
#       5 if response.status_code != 200:
#       6     raise Exception(
#       7         "Cannot get stream (HTTP {}): {}".format(
#       8             response.status_code, response.text
#       9         )
#      10     )
# ---> 11 for i, response_line in enumerate(response.iter_lines()):
#      12     if response_line:
#      13         json_response = json.loads(response_line)
#
# File /opt/anaconda3/envs/big-data-proj/lib/python3.8/site-packages/requests/models.py:865, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     856 """Iterates over the response data, one line at a time.  When
#     857 stream=True is set on the request, this avoids reading the
#     858 content at once into memory for large responses.
#     859
#     860 .. note:: This method is not reentrant safe.
#     861 """
#     863 pending = None
# --> 865 for chunk in self.iter_content(
#     866     chunk_size=chunk_size, decode_unicode=decode_unicode
#     867 ):
#     869     if pending is not None:
#     870         chunk = pending + chunk
#
# File /opt/anaconda3/envs/big-data-proj/lib/python3.8/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File /opt/anaconda3/envs/big-data-proj/lib/python3.8/site-packages/urllib3/response.py:623, in HTTPResponse.stream(self, amt, decode_content)
#     607 """
#     608 A generator wrapper for the read() method. A call will block until
#     609 ``amt`` bytes have been read from the connection or until the
#    (...)
#     620     'content-encoding' header.
#     621 """
#     622 if self.chunked and self.supports_chunked_reads():
# --> 623     for line in self.read_chunked(amt, decode_content=decode_content):
#     624         yield line
#     625 else:
#
# File /opt/anaconda3/envs/big-data-proj/lib/python3.8/site-packages/urllib3/response.py:815, in HTTPResponse.read_chunked(self, amt, decode_content)
#     812     return
#     814 while True:
# --> 815     self._update_chunk_length()
#     816     if self.chunk_left == 0:
#     817         break
#
# File /opt/anaconda3/envs/big-data-proj/lib/python3.8/site-packages/urllib3/response.py:745, in HTTPResponse._update_chunk_length(self)
#     743 if self.chunk_left is not None:
#     744     return
# --> 745 line = self._fp.fp.readline()
#     746 line = line.split(b";", 1)[0]
#     747 try:
#
# File /opt/anaconda3/envs/big-data-proj/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File /opt/anaconda3/envs/big-data-proj/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/envs/big-data-proj/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
get_stream(r_set)
# Out:
# 200
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192154794659840"
#         ],
#         "id": "1598192154794659840",
#         "text": "RT @dangan_cat: \u3044\u3044\u306b\u304f\u306e\u3072\u30b9\u30b1\u30d6\u7d75\ud83e\udd8a https://t.co/ugWoT6VbHc"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192156199780353"
#         ],
#         "id": "1598192156199780353",
#         "text": "\u671f\u672b\u8a66\u9a13\u521d\u65e5\u304b\u3089\u5e30\u5b85\u3057\u305f\u3001\u304a\u5144\u3061\u3083\u3093\u305d\u306e2\u3068\u4e00\u7dd2\u306b\u304a\u663c\u5bdd\u3059\u308b\u4e8b\u306b\u3057\u305f\u96ea\u3055\u307e\n#mnc_cat https://t.co/hQKje7pGJz"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192159777165312"
#         ],
#         "id": "1598192159777165312",
#         "text": "\u30c1\u30fc\u3055\u3093\u3001\u3061\u3087\u3063\u3068\u30b9\u30ea\u30e0\u306b\u306a\u3063\u305f\u306e\u3067\u3001\u30ad\u30e3\u30c3\u30c8\u30bf\u30ef\u30fc\u306e\u4e0a\u308a\u4e0b\u308a\u304c\u697d\u306b\u306a\u3063\u305f\u3088\u3046\u3060\u3002\n\n\u3067\u3082\u3001\u98db\u3073\u964d\u308a\u308b\u77ac\u9593\u306f\u3061\u3087\u3063\u3068\u30d2\u30e4\u30ea\u3068\u3059\u308b(\uff1b\u00b4\u0414\uff40) https://t.co/qmbww2btLq"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192161597554688"
#         ],
#         "id": "1598192161597554688",
#         "text": "RT @cat_auras: https://t.co/lVn69HPLqC"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192163170705412"
#         ],
#         "id": "1598192163170705412",
#         "text": "RT @yangwonbear: its so cat behavior \ud83e\udd79 https://t.co/Umdz2UnD7S"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192160721244160"
#         ],
#         "id": "1598192160721244160",
#         "text": "RT @cat_auras: https://t.co/ASbBYqUGuC"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192164126662656"
#         ],
#         "id": "1598192164126662656",
#         "text": "@ottoscreams Good idea Otto. I\u2019m already sleeping so I can wake up during the wee hours in celebration of cat time! https://t.co/7ASohBwA6S"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192171710316544"
#         ],
#         "id": "1598192171710316544",
#         "text": "RT @lightCC2: Black Dog : Thank You Teacher (Thai Ver.)\n\nBlack Dog : Being A Teacher (Korean Ver.) https://t.co/1kOcJrSzyn"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601218",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192173853593600"
#         ],
#         "id": "1598192173853593600",
#         "text": "RT @michaelscat2: buffins, winner of the title of 'cat with the most appealing expression' in 1958. https://t.co/NMEf3Dgwer"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192180098928640"
#         ],
#         "id": "1598192180098928640",
#         "text": "RT @cat_auras: https://t.co/lVn69HPLqC"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192179524296709"
#         ],
#         "id": "1598192179524296709",
#         "text": "this is reina, she has no idea what\u2019s going on ever https://t.co/waxP00QX9a https://t.co/20qwyR5Z05"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192184762675201"
#         ],
#         "id": "1598192184762675201",
#         "text": "@pepepepitopepo6 @IntoMari @pizzaconpina65 @RepiladorB @dnicatala @Ozzze @joantuiter @lluismunyoz1 @MesallesXavier @teuavlc @Pelikano8 @lovenjaire @gvergarasim @NICOLAS83665850 @aor2860 @Gustaff69 @Superlpez5 @Fxsoria @DI48630499 @Luis_Sala_D @bertamontanerfa @Berxat @lotraigue @javigonval @Batman76870205 @ElDelFairy @Mo66452567 @Pesadilla8888 @JoandeSerrallo1 @acorey_cat @andreucanals @ocirelos @JeorjeBulls1 @adrianatura11 @Annuska34 @UnitatxIndep @gofrancesc @jpascualt @CDRCatOficial @cdr_stroures @CDR_SColomaC @CDRxavimastrat @ComiteGracia @CDRacciodirecta @Susber31 @MestreYorda @RosaMar90969705 @mantincelcatala @Meritxelllavall @josepcosta https://t.co/gpIWcZacbA"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192189510934528"
#         ],
#         "id": "1598192189510934528",
#         "text": "RT @cat_56chan: \u5f1f\u304c\u64ae\u3063\u3066\u304f\u308c\u305f\u3084\u3064\u3067\u3059 https://t.co/oCXltoMfi7"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192191720939522"
#         ],
#         "id": "1598192191720939522",
#         "text": "https://t.co/t48B1a0uiY"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192193172557824"
#         ],
#         "id": "1598192193172557824",
#         "text": "RT @Cat_Adonis25: \u30c1\u30ea\u3061\u3083\u3093\u304b\u308f\u3044\u3044\uff5e\uff5e\uff5e\uff5e\uff5e\uff5e\uff01\uff01\uff01\uff01\n\u307e\u3044\u3069\uff5e\uff5e\uff5e\uff5e\uff5e\uff5e\uff5e\uff5e\uff6f\uff6f\uff01\uff01\uff01\uff01\uff01 https://t.co/ZMvHkBqEfZ"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192193399066625"
#         ],
#         "id": "1598192193399066625",
#         "text": "@MichaelMetaETH @C_CryptoSkulls @Crypto_Skulls My dog does that too https://t.co/FmHx3NTAhv"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601218",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192192224645120"
#         ],
#         "id": "1598192192224645120",
#         "text": "RT @c2owh: The florist's son and his stray cat. https://t.co/34lkUQKH1X"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192194644738048"
#         ],
#         "id": "1598192194644738048",
#         "text": "RT @DreamerKnights: Angry Cat Mom https://t.co/67zc9M942D"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192199728259072"
#         ],
#         "id": "1598192199728259072",
#         "text": "RT @CatsOfYore: \"Herbert Tobias With His Cat, 1962\" https://t.co/7OB9K9GrH8 https://t.co/kpww6arZkM"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192196322205697"
#         ],
#         "id": "1598192196322205697",
#         "text": "Frente abierto y la nueva t\u00e1ctica de inseguridad en Guaymas &gt; https://t.co/o1NPP9oPO4 https://t.co/H5n1lzJAhJ"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192206493675525"
#         ],
#         "id": "1598192206493675525",
#         "text": "RT @haerinspic: cat eyes https://t.co/8NEIrXr6Pp"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192202945298434"
#         ],
#         "id": "1598192202945298434",
#         "text": "relationships with professors in graduate programs are so different than undergrad, today my prof asked if I\u2019d walk her dog for her while she logged into a zoom meeting LOL https://t.co/x30Ny17wRU"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601218",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192215234580480"
#         ],
#         "id": "1598192215234580480",
#         "text": "RT @cat_dot_exe: https://t.co/hJ79Na1XPA"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192214051782656"
#         ],
#         "id": "1598192214051782656",
#         "text": "RT @SethAbramson: Time to leave the bird site for the dog site: https://t.co/derfTHaIMC. https://t.co/9i1C09YRM7"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601218",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192221781884928"
#         ],
#         "id": "1598192221781884928",
#         "text": "@todayjumil \uc640\uac10\uc0ac\ud569\ub2c8\ub2e4 \uc804\ud600\ub2e4\ub978\uac70\uc600\ub124\uc694 https://t.co/8jlHUfu2t6"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601218",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192223421886465"
#         ],
#         "id": "1598192223421886465",
#         "text": "bet ur artist message didn\u2019t include a dog haha https://t.co/HFuM8ctKI4"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601218",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192224067809285"
#         ],
#         "id": "1598192224067809285",
#         "text": "RT @cat_auras: https://t.co/ICmtCSt6Er"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192226718261254"
#         ],
#         "id": "1598192226718261254",
#         "text": "@lifestyle_a2z Mixed breeds are the best\ud83d\ude01 https://t.co/p6QebmeP2j"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601218",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192228723093504"
#         ],
#         "id": "1598192228723093504",
#         "text": "RT @bexjuIes: dog dean afternoon https://t.co/yAPVGzqGW9"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601218",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192228169842690"
#         ],
#         "id": "1598192228169842690",
#         "text": "RT @beaujeweIed: \u3164\u3164\u3164\u3164\u3164\n\u66f4\u65b0\uff1aMy mom gave me a dog as a birthday present. What should I name this little cutie? \n\u3164\u3164\u3164\u3164\u3164 https://t.co/oC5iKNm5tW"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601218",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192233966350336"
#         ],
#         "id": "1598192233966350336",
#         "text": "@barkmeta https://t.co/5nPhoDjuu4"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601218",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192242769899520"
#         ],
#         "id": "1598192242769899520",
#         "text": "RT @MoxieBoosted: Dog Dad, Nerd, and Goku &gt;&gt;&gt; Person, Person, and Person who dances https://t.co/AEw1AtFFJd"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601218",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192244405972992"
#         ],
#         "id": "1598192244405972992",
#         "text": "RT @cat_auras: https://t.co/lVn69HPLqC"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192252857171970"
#         ],
#         "id": "1598192252857171970",
#         "text": "@EmiiJ4mes I DONT WANT MORE RABIES IM SORRY https://t.co/RsJXS8pf2m"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "edit_history_tweet_ids": [
#             "1598192260805713921"
#         ],
#         "id": "1598192260805713921",
#         "text": "RT @cat_auras: https://t.co/l2siGq8YH6"
#     },
#     "matching_rules": [
#         {
#             "id": "1598192126302601217",
#             "tag": "cat pictures"
#         }
#     ]
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 get_stream(r_set)
#
# Cell In [1], line 83, in get_stream(set)
#      77 if response.status_code != 200:
#      78     raise Exception(
#      79         "Cannot get stream (HTTP {}): {}".format(
#      80             response.status_code, response.text
#      81         )
#      82     )
# ---> 83 for i, response_line in enumerate(response.iter_lines()):
#      84     if response_line:
#      85         json_response = json.loads(response_line)
#
# File /opt/anaconda3/envs/big-data-proj/lib/python3.8/site-packages/requests/models.py:865, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     856 """Iterates over the response data, one line at a time.  When
#     857 stream=True is set on the request, this avoids reading the
#     858 content at once into memory for large responses.
#     859
#     860 .. note:: This method is not reentrant safe.
#     861 """
#     863 pending = None
# --> 865 for chunk in self.iter_content(
#     866     chunk_size=chunk_size, decode_unicode=decode_unicode
#     867 ):
#     869     if pending is not None:
#     870         chunk = pending + chunk
#
# File /opt/anaconda3/envs/big-data-proj/lib/python3.8/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File /opt/anaconda3/envs/big-data-proj/lib/python3.8/site-packages/urllib3/response.py:623, in HTTPResponse.stream(self, amt, decode_content)
#     607 """
#     608 A generator wrapper for the read() method. A call will block until
#     609 ``amt`` bytes have been read from the connection or until the
#    (...)
#     620     'content-encoding' header.
#     621 """
#     622 if self.chunked and self.supports_chunked_reads():
# --> 623     for line in self.read_chunked(amt, decode_content=decode_content):
#     624         yield line
#     625 else:
#
# File /opt/anaconda3/envs/big-data-proj/lib/python3.8/site-packages/urllib3/response.py:815, in HTTPResponse.read_chunked(self, amt, decode_content)
#     812     return
#     814 while True:
# --> 815     self._update_chunk_length()
#     816     if self.chunk_left == 0:
#     817         break
#
# File /opt/anaconda3/envs/big-data-proj/lib/python3.8/site-packages/urllib3/response.py:745, in HTTPResponse._update_chunk_length(self)
#     743 if self.chunk_left is not None:
#     744     return
# --> 745 line = self._fp.fp.readline()
#     746 line = line.split(b";", 1)[0]
#     747 try:
#
# File /opt/anaconda3/envs/big-data-proj/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File /opt/anaconda3/envs/big-data-proj/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/envs/big-data-proj/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:
